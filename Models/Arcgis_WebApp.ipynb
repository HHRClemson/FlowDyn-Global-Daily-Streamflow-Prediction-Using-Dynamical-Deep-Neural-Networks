# %% [markdown]
# ## Welcome to your notebook.

# %% [markdown]
# #### Run this cell to connect to your GIS and get started:

# %%
import os
import json
from IPython.display import display
import arcgis
from arcgis.gis import GIS
from arcgis.mapping import WebMap, WebScene
import ipywidgets
gis = GIS("home")

# %% [markdown]
# #### Now you are ready to start!

# %%
# wm = WebMap()
# wm.definition
# #Publish the map
# web_map_properties = {'title':'MDM python created map',
#                      'snippet':'This map for project purpose',
#                      'tags':'MDM'}

# # Call the save() with web map item's properties.
# web_map_item = wm.save(item_properties=web_map_properties)
# web_map_item

# %%
#m = gis.map()
#for i in public_content[0].layers: 
    #print(i)
#print(public_content[0].layers[1])
#m.add_layer(public_content[0].layers[1])
#m

# %%
gis = GIS()
m = gis.map()

# Watershed: NA

public_content = gis.content.search(query="title:hybas_na_lev04_v1c",item_type="Feature Layer")
for layer in public_content[0].layers: 
        sym = layer.symbology
        sym.renderer.symbol.color = {'RGB': [10, 10, 10, 255]}
        layer.symbology = sym
        m.add_layer(layer)
m

# %%
# Plotting MAPS
gis = GIS()
m = gis.map()

# Watershed: NA

public_content = gis.content.search(query="title:hybas_na_lev04_v1c",item_type="Feature Layer")
item_data = public_content[0].get_data()
print(item_data)
field_infos = item_data['layers'][0]['popupInfo']['fieldInfos']
for field in field_infos:
    field["visible"] = False
item_properties = {"text": json.dumps(item_data)}
#public_content[0].update(item_properties=item_properties)
for layer in public_content[0].layers: 
     m.add_layer(layer)

# Watershed: SA

public_content = gis.content.search(query="title:hybas_sa_lev04_v1c",item_type="Feature Layer")
item_data = public_content[0].get_data()
#print(item_data)
field_infos = item_data['layers'][0]['popupInfo']['fieldInfos']
for field in field_infos:
    field["visible"] = False
item_properties = {"text": json.dumps(item_data)}
#public_content[0].update(item_properties=item_properties)
print(public_content[0].access)
for layer in public_content[0].layers: 
     m.add_layer(layer)

# Watershed: AF

public_content = gis.content.search(query="title:hybas_af_lev04_v1c",item_type="Feature Layer")
item_data = public_content[0].get_data()
#print(item_data)
field_infos = item_data['layers'][0]['popupInfo']['fieldInfos']
for field in field_infos:
    field["visible"] = False
item_properties = {"text": json.dumps(item_data)}
#public_content[0].update(item_properties=item_properties)
print(public_content[0].access)
for layer in public_content[0].layers: 
     m.add_layer(layer)

# River Networks: NA

public_content = gis.content.search(query="title:na_riv_30s",item_type="Feature Layer")
item_data = public_content[0].get_data()
#print(item_data)
field_infos = item_data['layers'][0]['popupInfo']['fieldInfos']
for field in field_infos:
    field["visible"] = False
item_properties = {"text": json.dumps(item_data)}
#public_content[0].update(item_properties=item_properties)
print(public_content[0].access)
for layer in public_content[0].layers: 
     m.add_layer(layer)

# River Networks: SA
public_content = gis.content.search(query="title:sa_riv_30s",item_type="Feature Layer")
item_data = public_content[0].get_data()
#print(item_data)
field_infos = item_data['layers'][0]['popupInfo']['fieldInfos']
for field in field_infos:
    field["visible"] = False
item_properties = {"text": json.dumps(item_data)}
#public_content[0].update(item_properties=item_properties)
print(public_content[0].access)
for layer in public_content[0].layers: 
             m.add_layer(layer)

# River Networks: AF

public_content = gis.content.search(query="title:africa_riv_30s",item_type="Feature Layer")
item_data = public_content[0].get_data()
#print(item_data)
field_infos = item_data['layers'][0]['popupInfo']['fieldInfos']
for field in field_infos:
    field["visible"] = False
item_properties = {"text": json.dumps(item_data)}
#public_content[0].update(item_properties=item_properties)
print(public_content[0].access)
for layer in public_content[0].layers: 
             m.add_layer(layer)

# Rainfall Stations: AF

public_content = gis.content.search(query="title:rain_africa",item_type="Feature Layer")
item_data = public_content[0].get_data()
#print(item_data)
field_infos = item_data['layers'][0]['popupInfo']['fieldInfos']
for field in field_infos:
    field["visible"] = False
item_properties = {"text": json.dumps(item_data)}
#public_content[0].update(item_properties=item_properties)
print(public_content[0].access)
for layer in public_content[0].layers: 
     m.add_layer(layer)

# Rainfall Stations: America

public_content = gis.content.search(query="title:rain_america",item_type="Feature Layer")
item_data = public_content[0].get_data()
#print(item_data)
field_infos = item_data['layers'][0]['popupInfo']['fieldInfos']
for field in field_infos:
    field["visible"] = False
item_properties = {"text": json.dumps(item_data)}
#public_content[0].update(item_properties=item_properties)
print(public_content[0].access)
for layer in public_content[0].layers: 
     m.add_layer(layer)
        
# Runoff Stations: All

public_content = gis.content.search(query="title:runoff_stations",item_type="Feature Layer")
item_data = public_content[0].get_data()
#print(item_data)
field_infos = item_data['layers'][0]['popupInfo']['fieldInfos']
for field in field_infos:
    field["visible"] = False
item_properties = {"text": json.dumps(item_data)}
#public_content[0].update(item_properties=item_properties)
print(public_content[0].access)
for layer in public_content[0].layers: 
     m.add_layer(layer)
        
        
m

# %%
m.export_to_html('/arcgis/home/map_10.19.html')

# %%
import json
def load_tester(path):
    with open(path) as f:
        data = json.load(f)
    print(data)
    return np.asarray(data)

# %%
dataset = '/arcgis/home/allregion_stations_2.csv'
df = pd.read_csv(dataset, sep=',')
df = df.dropna()
df['lat'] = df.loc[:,['lat']].astype('float64')
df['long'] = df.loc[:,['long']].astype('float64')

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
def plots():
    

    # Fixing random state for reproducibility
    np.random.seed(19680801)

    dt = 0.01
    t = np.arange(0, 30, dt)
    nse1 = np.random.randn(len(t))                 # white noise 1
    nse2 = np.random.randn(len(t))                 # white noise 2

    # Two signals with a coherent part at 10Hz and a random part
    s1 = np.sin(2 * np.pi * 10 * t) + nse1
    s2 = np.sin(2 * np.pi * 10 * t) + nse2

    fig, axs = plt.subplots(2, 1)
    axs[0].plot(t, s1, t, s2)
    axs[0].set_xlim(0, 2)
    axs[0].set_xlabel('time')
    axs[0].set_ylabel('s1 and s2')
    axs[0].grid(True)

    cxy, f = axs[1].cohere(s1, s2, 256, 1. / dt)
    axs[1].set_ylabel('coherence')

    fig.tight_layout()
    plt.show()

# %%
from arcgis import geometry
from arcgis import features
point_dict = {}
global object_id
def find_addr(m, g):
    try:
        print(g.type)
        m.display_message(g.type)
        #print("Clicked")
        #callback_map.draw(g)
        

        #geocoded = geocoding.reverse_geocode(g)
        #print(geocoded[0])
        #print(geocoded['address']['Match_addr'])
    except:
        print("Couldn't match address. Try another place...")
        
def create_feature(_map, location):
    try:
        
        point = geometry.Point(location)
        input_geometry = {'x':point.x,'y':point.y}
        output_geometry=geometry.project(geometries=[input_geometry],in_sr = 3857, out_sr = 4326)
        point_dict[point] = output_geometry[0] #output_geometry
        print(output_geometry[0]['x'])
        #plots()
        #feature = features.Feature(
            #geometry=point,
            #attributes={
                #'OBJECTID': object_id,
                #'PARK_NAME': 'My Park',
                #'TRL_NAME': 'Foobar Trail',
                #'ELEV_FT': '5000'
            #}
        #)

        #trailheads_layer.edit_features(adds=[feature])
        #_map.draw(point)

    except Exception as e:
        print("Couldn't create the feature. {}".format(str(e)))        
m.on_click(create_feature)
m

# %%
point_dict
